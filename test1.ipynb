# %%
from generator import Generator


gen = Generator()

# %%
gen.get(['A','D','A','R','K','W','<EOS>'])
#gen.get(['A','K', 'Y','D', '<EOS>'])

# for the last item second and third


# 3.65, 10.529,10.06, 9.600000381469727,3.6500000953674316

#starting D carb is arrached to surface
# Free is side chain and amine

#Amine of D attached to carb of K,

# This will only affect the end of the chain
# carb - 1st Value
# Amine - 2nd value
# If it starts with Carb - ends with Amine
# If it starts with Amine - ends with CArb
# Out:
# N: 3 M: 1
# [1.00000000e+00 2.23872065e-04 4.07379956e-10 2.95121104e-11
#  3.31131471e-13]
# [ 1.30104261e-18  6.50521303e-19 -6.50521303e-19 ...  3.86420532e-08
#   2.85997623e-08  1.89400215e-08]
# [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -1.68693608e-09
#  -1.24992586e-09 -8.28214705e-10]
# (array([1045, 1199, 1228,    0]), array([1012, 1278,    0]))
